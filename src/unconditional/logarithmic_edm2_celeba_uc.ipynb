# %%
# ============================================================
# ✅ SETUP
# ============================================================

# !git clone https://github.com/NVlabs/edm2.git /kaggle/working/edm2
# %cd /kaggle/working/edm2
# !pip install click tqdm psutil scipy pillow --quiet
# %cd /kaggle/working/edm2
# Out:
# Cloning into '/kaggle/working/edm2'...
# remote: Enumerating objects: 60, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 60 (delta 13), reused 10 (delta 10), pack-reused 33 (from 1)
# Receiving objects: 100% (60/60), 1.27 MiB | 10.34 MiB/s, done.
# Resolving deltas: 100% (24/24), done.
# /kaggle/working/edm2
# /kaggle/working/edm2

# %%
# ============================================================
# ✅ PATCH: LOGARITHMIC TRAINING NOISE SCHEDULE
# ============================================================
import torch
import training.training_loop as loop

def logarithmic_sigma(batch_size, device, sigma_min=0.002, sigma_max=80):
    """
    Sample sigma logarithmically from sigma_max → sigma_min.
    t ~ U[0,1]
    sigma(t) = 10^( log10(sigma_max) - t*(log10(sigma_max) - log10(sigma_min)) )
    """
    t = torch.rand(batch_size, 1, 1, 1, device=device)

    log_max = torch.log10(torch.tensor(sigma_max, device=device))
    log_min = torch.log10(torch.tensor(sigma_min, device=device))

    log_sigma = log_max + t * (log_min - log_max)
    return torch.pow(10.0, log_sigma)


def patched_call(self, net, images, labels=None):
    """
    Overrides EDM2Loss.__call__ with a logarithmic sigma schedule.
    """
    batch = images.shape[0]

    # === LOGARITHMIC NOISE SCHEDULE ===
    sigma = logarithmic_sigma(batch, images.device)

    # === EDM2 weighting ===
    weight = (sigma**2 + self.sigma_data**2) / (sigma * self.sigma_data)**2

    # Add noise
    noise = torch.randn_like(images) * sigma

    # Forward network
    denoised, logvar = net(images + noise, sigma, labels, return_logvar=True)

    # Loss
    loss = (weight / logvar.exp()) * ((denoised - images)**2) + logvar
    return loss


# Inject patch
loop.EDM2Loss.__call__ = patched_call

print("✅ Logarithmic training schedule injected successfully!")
# Out:
# ✅ Logarithmic training schedule injected successfully!

# %%
# !torchrun --standalone --nproc_per_node=2 train_edm2.py \
    --outdir=/kaggle/working/training-runs/celeba64-edm2-logarithmic-noise-inject2 \
    --data=/kaggle/input/celeva-64x64-dataset/celeba64/train \
    --cond=False \
    --preset=edm2-img64-xs \
    --batch=64 \
    --batch-gpu=32 \
    --duration=2Mi \
    --status=16Ki \
    --snapshot=256Ki \
    --checkpoint=0 \
    --seed=0
# Out:
# W1114 02:57:11.076000 54 torch/distributed/run.py:792]
# W1114 02:57:11.076000 54 torch/distributed/run.py:792] *****************************************
# W1114 02:57:11.076000 54 torch/distributed/run.py:792] Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# W1114 02:57:11.076000 54 torch/distributed/run.py:792] *****************************************
# [W1114 02:57:21.904045632 socket.cpp:204] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# [W1114 02:57:31.914050664 socket.cpp:204] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# [W1114 02:57:42.618581984 socket.cpp:204] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# [W1114 02:57:42.619066192 socket.cpp:204] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# [W1114 02:57:52.629052445 socket.cpp:204] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# [W1114 02:58:02.639442773 socket.cpp:204] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# Setting up training config...
#
# Training config:
# {
#   "dataset_kwargs": {
#     "class_name": "training.dataset.ImageFolderDataset",
#     "path": "/kaggle/input/celeva-64x64-dataset/celeba64/train",
#     "use_labels": false
#   },
#   "encoder_kwargs": {
#     "class_name": "training.encoders.StandardRGBEncoder"
#   },
#   "total_nimg": 2097152,
#   "batch_size": 64,
#   "network_kwargs": {
#     "class_name": "training.networks_edm2.Precond",
#     "model_channels": 128,
#     "dropout": 0.0,
#     "use_fp16": true
#   },
#   "loss_kwargs": {
#     "class_name": "training.training_loop.EDM2Loss",
#     "P_mean": -0.8,
#     "P_std": 1.6
#   },
#   "lr_kwargs": {
#     "func_name": "training.training_loop.learning_rate_schedule",
#     "ref_lr": 0.012,
#     "ref_batches": 35000
#   },
#   "batch_gpu": 32,
#   "loss_scaling": 1.0,
#   "cudnn_benchmark": true,
#   "status_nimg": 16384,
#   "snapshot_nimg": 262144,
#   "checkpoint_nimg": null,
#   "seed": 0
# }
#
# Output directory:        /kaggle/working/training-runs/celeba64-edm2-logarithmic-noise-inject2
# Dataset path:            /kaggle/input/celeva-64x64-dataset/celeba64/train
# Class-conditional:       False
# Number of GPUs:          2
# Batch size:              64
# Mixed-precision:         True
#
# Creating output directory...
# [rank1]:[W1114 03:04:50.022034118 ProcessGroupNCCL.cpp:4561] [PG ID 0 PG GUID 0 Rank 1]  using GPU 1 to perform barrier as devices used by this process are currently unknown. This can potentially cause a hang if this rank to GPU mapping is incorrect. Specify device_ids in barrier() to force use of a particular device, or call init_process_group() with a device_id.
# [rank0]:[W1114 03:04:50.132430572 ProcessGroupNCCL.cpp:4561] [PG ID 0 PG GUID 0 Rank 0]  using GPU 0 to perform barrier as devices used by this process are currently unknown. This can potentially cause a hang if this rank to GPU mapping is incorrect. Specify device_ids in barrier() to force use of a particular device, or call init_process_group() with a device_id.
# Loading dataset...
# Setting up encoder...
# Constructing network...
#
# Precond                Parameters  Buffers  Output shape       Datatype
# ---                    ---         ---      ---                ---
# unet.emb_fourier       -           256      [32, 128]          float32
# unet.emb_noise         65536       -        [32, 512]          float32
# unet.enc.64x64_conv    4608        -        [32, 128, 64, 64]  float16
# unet.enc.64x64_block0  360449      -        [32, 128, 64, 64]  float16
# unet.enc.64x64_block1  360449      -        [32, 128, 64, 64]  float16
# unet.enc.64x64_block2  360449      -        [32, 128, 64, 64]  float16
# unet.enc.32x32_down    360449      -        [32, 128, 32, 32]  float16
# unet.enc.32x32_block0  1343489     -        [32, 256, 32, 32]  float16
# unet.enc.32x32_block1  1310721     -        [32, 256, 32, 32]  float16
# unet.enc.32x32_block2  1310721     -        [32, 256, 32, 32]  float16
# unet.enc.16x16_down    1310721     -        [32, 256, 16, 16]  float16
# unet.enc.16x16_block0  3538945     -        [32, 384, 16, 16]  float16
# unet.enc.16x16_block1  3440641     -        [32, 384, 16, 16]  float16
# unet.enc.16x16_block2  3440641     -        [32, 384, 16, 16]  float16
# unet.enc.8x8_down      2850817     -        [32, 384, 8, 8]    float16
# unet.enc.8x8_block0    6225921     -        [32, 512, 8, 8]    float16
# unet.enc.8x8_block1    6029313     -        [32, 512, 8, 8]    float16
# unet.enc.8x8_block2    6029313     -        [32, 512, 8, 8]    float16
# unet.dec.8x8_in0       6029313     -        [32, 512, 8, 8]    float16
# unet.dec.8x8_in1       4980737     -        [32, 512, 8, 8]    float16
# unet.dec.8x8_block0    8912897     -        [32, 512, 8, 8]    float16
# unet.dec.8x8_block1    8912897     -        [32, 512, 8, 8]    float16
# unet.dec.8x8_block2    8912897     -        [32, 512, 8, 8]    float16
# unet.dec.8x8_block3    8257537     -        [32, 512, 8, 8]    float16
# unet.dec.16x16_up      4980737     -        [32, 512, 16, 16]  float16
# unet.dec.16x16_block0  5554177     -        [32, 384, 16, 16]  float16
# unet.dec.16x16_block1  5062657     -        [32, 384, 16, 16]  float16
# unet.dec.16x16_block2  5062657     -        [32, 384, 16, 16]  float16
# unet.dec.16x16_block3  4571137     -        [32, 384, 16, 16]  float16
# unet.dec.32x32_up      2850817     -        [32, 384, 32, 32]  float16
# unet.dec.32x32_block0  2359297     -        [32, 256, 32, 32]  float16
# unet.dec.32x32_block1  2031617     -        [32, 256, 32, 32]  float16
# unet.dec.32x32_block2  2031617     -        [32, 256, 32, 32]  float16
# unet.dec.32x32_block3  1703937     -        [32, 256, 32, 32]  float16
# unet.dec.64x64_up      1310721     -        [32, 256, 64, 64]  float16
# unet.dec.64x64_block0  704513      -        [32, 128, 64, 64]  float16
# unet.dec.64x64_block1  540673      -        [32, 128, 64, 64]  float16
# unet.dec.64x64_block2  540673      -        [32, 128, 64, 64]  float16
# unet.dec.64x64_block3  540673      -        [32, 128, 64, 64]  float16
# unet.out_conv          3456        -        [32, 3, 64, 64]    float16
# unet                   1           -        [32, 3, 64, 64]    float16
# <top-level>            128         256      [32, 3, 64, 64]    float32
# ---                    ---         ---      ---                ---
# Total                  124198949   512      -                  -
#
# Setting up training state...
# Training from 0 kimg to 2097 kimg:
#
# Status: kimg 0.0       time 1m 56s       sec/tick 115.71   sec/kimg 0.000   maintenance 115.71  cpumem 2.44   gpumem 1.87   reserved 2.24
# Saving network-snapshot-0000000-0.050.pkl ... done
# Saving network-snapshot-0000000-0.100.pkl ... done
# Status: kimg 16.4      time 6m 01s       sec/tick 244.91   sec/kimg 14.839  maintenance 1.79    cpumem 2.87   gpumem 7.71   reserved 8.04
# Status: kimg 32.8      time 10m 04s      sec/tick 243.70   sec/kimg 14.865  maintenance 0.15    cpumem 2.87   gpumem 7.71   reserved 8.04
# Status: kimg 49.2      time 14m 09s      sec/tick 244.63   sec/kimg 14.922  maintenance 0.15    cpumem 2.87   gpumem 7.71   reserved 8.04
# Status: kimg 65.5      time 18m 14s      sec/tick 244.70   sec/kimg 14.926  maintenance 0.15    cpumem 2.87   gpumem 7.71   reserved 8.04
# Status: kimg 81.9      time 22m 19s      sec/tick 245.45   sec/kimg 14.971  maintenance 0.16    cpumem 2.87   gpumem 7.71   reserved 8.04
# Status: kimg 98.3      time 26m 25s      sec/tick 246.14   sec/kimg 15.014  maintenance 0.16    cpumem 2.87   gpumem 7.71   reserved 8.04
# Status: kimg 114.7     time 30m 32s      sec/tick 246.76   sec/kimg 15.052  maintenance 0.15    cpumem 2.87   gpumem 7.71   reserved 8.04
# Status: kimg 131.1     time 34m 39s      sec/tick 246.54   sec/kimg 15.038  maintenance 0.16    cpumem 2.87   gpumem 7.71   reserved 8.04
# Status: kimg 147.5     time 38m 46s      sec/tick 247.96   sec/kimg 15.125  maintenance 0.16    cpumem 2.87   gpumem 7.71   reserved 8.04
# Status: kimg 163.8     time 42m 54s      sec/tick 247.53   sec/kimg 15.099  maintenance 0.14    cpumem 2.87   gpumem 7.71   reserved 8.04
# Status: kimg 180.2     time 47m 02s      sec/tick 247.86   sec/kimg 15.119  maintenance 0.15    cpumem 2.87   gpumem 7.71   reserved 8.04
# Status: kimg 196.6     time 51m 10s      sec/tick 248.20   sec/kimg 15.139  maintenance 0.15    cpumem 2.87   gpumem 7.71   reserved 8.04
# Status: kimg 213.0     time 55m 19s      sec/tick 249.20   sec/kimg 15.200  maintenance 0.17    cpumem 2.87   gpumem 7.71   reserved 8.04
# Status: kimg 229.4     time 59m 28s      sec/tick 248.25   sec/kimg 15.142  maintenance 0.16    cpumem 2.87   gpumem 7.71   reserved 8.04
# Status: kimg 245.8     time 1h 03m 36s   sec/tick 248.76   sec/kimg 15.174  maintenance 0.16    cpumem 2.87   gpumem 7.71   reserved 8.04
# Status: kimg 262.1     time 1h 07m 46s   sec/tick 249.66   sec/kimg 15.228  maintenance 0.16    cpumem 2.87   gpumem 7.71   reserved 8.04
# Saving network-snapshot-0000262-0.050.pkl ... done
# Saving network-snapshot-0000262-0.100.pkl ... done
# Status: kimg 278.5     time 1h 11m 57s   sec/tick 250.71   sec/kimg 15.219  maintenance 1.37    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 294.9     time 1h 16m 06s   sec/tick 249.27   sec/kimg 15.205  maintenance 0.16    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 311.3     time 1h 20m 15s   sec/tick 248.91   sec/kimg 15.183  maintenance 0.15    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 327.7     time 1h 24m 24s   sec/tick 249.52   sec/kimg 15.220  maintenance 0.15    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 344.1     time 1h 28m 34s   sec/tick 249.23   sec/kimg 15.202  maintenance 0.16    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 360.4     time 1h 32m 43s   sec/tick 249.70   sec/kimg 15.231  maintenance 0.15    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 376.8     time 1h 36m 52s   sec/tick 248.72   sec/kimg 15.172  maintenance 0.15    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 393.2     time 1h 41m 02s   sec/tick 249.59   sec/kimg 15.224  maintenance 0.16    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 409.6     time 1h 45m 11s   sec/tick 248.90   sec/kimg 15.183  maintenance 0.15    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 426.0     time 1h 49m 21s   sec/tick 250.06   sec/kimg 15.253  maintenance 0.16    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 442.4     time 1h 53m 31s   sec/tick 250.37   sec/kimg 15.271  maintenance 0.16    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 458.8     time 1h 57m 41s   sec/tick 249.83   sec/kimg 15.238  maintenance 0.16    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 475.1     time 2h 01m 50s   sec/tick 249.09   sec/kimg 15.194  maintenance 0.16    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 491.5     time 2h 06m 00s   sec/tick 249.76   sec/kimg 15.235  maintenance 0.16    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 507.9     time 2h 10m 08s   sec/tick 248.66   sec/kimg 15.167  maintenance 0.16    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 524.3     time 2h 14m 17s   sec/tick 248.84   sec/kimg 15.178  maintenance 0.16    cpumem 3.23   gpumem 7.71   reserved 8.04
# Saving network-snapshot-0000524-0.050.pkl ... done
# Saving network-snapshot-0000524-0.100.pkl ... done
# Status: kimg 540.7     time 2h 18m 27s   sec/tick 250.03   sec/kimg 15.193  maintenance 1.10    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 557.1     time 2h 22m 36s   sec/tick 249.18   sec/kimg 15.199  maintenance 0.16    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 573.4     time 2h 26m 45s   sec/tick 249.11   sec/kimg 15.195  maintenance 0.16    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 589.8     time 2h 30m 55s   sec/tick 249.57   sec/kimg 15.223  maintenance 0.16    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 606.2     time 2h 35m 04s   sec/tick 248.84   sec/kimg 15.179  maintenance 0.15    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 622.6     time 2h 39m 13s   sec/tick 248.93   sec/kimg 15.184  maintenance 0.15    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 639.0     time 2h 43m 22s   sec/tick 249.15   sec/kimg 15.197  maintenance 0.16    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 655.4     time 2h 47m 31s   sec/tick 248.94   sec/kimg 15.184  maintenance 0.16    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 671.7     time 2h 51m 40s   sec/tick 249.22   sec/kimg 15.201  maintenance 0.16    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 688.1     time 2h 55m 49s   sec/tick 248.60   sec/kimg 15.164  maintenance 0.15    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 704.5     time 2h 59m 58s   sec/tick 248.89   sec/kimg 15.182  maintenance 0.15    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 720.9     time 3h 04m 07s   sec/tick 249.04   sec/kimg 15.190  maintenance 0.16    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 737.3     time 3h 08m 16s   sec/tick 249.48   sec/kimg 15.218  maintenance 0.15    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 753.7     time 3h 12m 25s   sec/tick 249.28   sec/kimg 15.205  maintenance 0.16    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 770.0     time 3h 16m 34s   sec/tick 248.83   sec/kimg 15.178  maintenance 0.15    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 786.4     time 3h 20m 43s   sec/tick 248.31   sec/kimg 15.146  maintenance 0.16    cpumem 3.23   gpumem 7.71   reserved 8.04
# Saving network-snapshot-0000786-0.050.pkl ... done
# Saving network-snapshot-0000786-0.100.pkl ... done
# Status: kimg 802.8     time 3h 24m 52s   sec/tick 249.35   sec/kimg 15.152  maintenance 1.10    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 819.2     time 3h 29m 00s   sec/tick 247.99   sec/kimg 15.127  maintenance 0.15    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 835.6     time 3h 33m 09s   sec/tick 248.85   sec/kimg 15.179  maintenance 0.16    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 852.0     time 3h 37m 17s   sec/tick 248.63   sec/kimg 15.166  maintenance 0.16    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 868.4     time 3h 41m 26s   sec/tick 248.72   sec/kimg 15.171  maintenance 0.16    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 884.7     time 3h 45m 35s   sec/tick 248.67   sec/kimg 15.169  maintenance 0.15    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 901.1     time 3h 49m 44s   sec/tick 249.04   sec/kimg 15.191  maintenance 0.16    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 917.5     time 3h 53m 52s   sec/tick 248.50   sec/kimg 15.158  maintenance 0.15    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 933.9     time 3h 58m 01s   sec/tick 249.16   sec/kimg 15.197  maintenance 0.17    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 950.3     time 4h 02m 11s   sec/tick 249.17   sec/kimg 15.198  maintenance 0.16    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 966.7     time 4h 06m 20s   sec/tick 249.09   sec/kimg 15.193  maintenance 0.17    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 983.0     time 4h 10m 29s   sec/tick 248.92   sec/kimg 15.184  maintenance 0.15    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 999.4     time 4h 14m 37s   sec/tick 248.23   sec/kimg 15.142  maintenance 0.16    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 1015.8    time 4h 18m 46s   sec/tick 248.76   sec/kimg 15.173  maintenance 0.16    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 1032.2    time 4h 22m 54s   sec/tick 248.73   sec/kimg 15.171  maintenance 0.16    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 1048.6    time 4h 27m 03s   sec/tick 248.32   sec/kimg 15.147  maintenance 0.16    cpumem 3.23   gpumem 7.71   reserved 8.04
# Saving network-snapshot-0001048-0.050.pkl ... done
# Saving network-snapshot-0001048-0.100.pkl ... done
# Status: kimg 1065.0    time 4h 31m 12s   sec/tick 249.25   sec/kimg 15.147  maintenance 1.09    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 1081.3    time 4h 35m 20s   sec/tick 248.09   sec/kimg 15.133  maintenance 0.16    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 1097.7    time 4h 39m 29s   sec/tick 248.68   sec/kimg 15.168  maintenance 0.16    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 1114.1    time 4h 43m 37s   sec/tick 248.46   sec/kimg 15.156  maintenance 0.15    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 1130.5    time 4h 47m 46s   sec/tick 248.77   sec/kimg 15.174  maintenance 0.15    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 1146.9    time 4h 51m 55s   sec/tick 248.64   sec/kimg 15.166  maintenance 0.16    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 1163.3    time 4h 56m 03s   sec/tick 248.38   sec/kimg 15.151  maintenance 0.15    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 1179.6    time 5h 00m 11s   sec/tick 248.36   sec/kimg 15.149  maintenance 0.16    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 1196.0    time 5h 04m 19s   sec/tick 247.87   sec/kimg 15.120  maintenance 0.15    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 1212.4    time 5h 08m 28s   sec/tick 248.62   sec/kimg 15.164  maintenance 0.17    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 1228.8    time 5h 12m 36s   sec/tick 248.17   sec/kimg 15.138  maintenance 0.15    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 1245.2    time 5h 16m 44s   sec/tick 247.97   sec/kimg 15.126  maintenance 0.15    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 1261.6    time 5h 20m 52s   sec/tick 248.39   sec/kimg 15.151  maintenance 0.16    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 1278.0    time 5h 25m 01s   sec/tick 248.30   sec/kimg 15.145  maintenance 0.16    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 1294.3    time 5h 29m 09s   sec/tick 247.91   sec/kimg 15.122  maintenance 0.15    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 1310.7    time 5h 33m 17s   sec/tick 248.56   sec/kimg 15.161  maintenance 0.16    cpumem 3.23   gpumem 7.71   reserved 8.04
# Saving network-snapshot-0001310-0.050.pkl ... done
# Saving network-snapshot-0001310-0.100.pkl ... done
# Status: kimg 1327.1    time 5h 37m 27s   sec/tick 249.47   sec/kimg 15.160  maintenance 1.09    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 1343.5    time 5h 41m 35s   sec/tick 248.46   sec/kimg 15.156  maintenance 0.15    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 1359.9    time 5h 45m 43s   sec/tick 248.40   sec/kimg 15.152  maintenance 0.15    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 1376.3    time 5h 49m 53s   sec/tick 249.15   sec/kimg 15.198  maintenance 0.16    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 1392.6    time 5h 54m 01s   sec/tick 248.31   sec/kimg 15.146  maintenance 0.16    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 1409.0    time 5h 58m 09s   sec/tick 248.22   sec/kimg 15.140  maintenance 0.17    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 1425.4    time 6h 02m 17s   sec/tick 248.25   sec/kimg 15.143  maintenance 0.15    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 1441.8    time 6h 06m 26s   sec/tick 248.98   sec/kimg 15.187  maintenance 0.15    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 1458.2    time 6h 10m 35s   sec/tick 249.06   sec/kimg 15.192  maintenance 0.15    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 1474.6    time 6h 14m 44s   sec/tick 248.26   sec/kimg 15.143  maintenance 0.16    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 1490.9    time 6h 18m 52s   sec/tick 248.00   sec/kimg 15.127  maintenance 0.15    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 1507.3    time 6h 23m 01s   sec/tick 249.30   sec/kimg 15.205  maintenance 0.18    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 1523.7    time 6h 27m 09s   sec/tick 248.13   sec/kimg 15.136  maintenance 0.15    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 1540.1    time 6h 31m 17s   sec/tick 247.79   sec/kimg 15.115  maintenance 0.15    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 1556.5    time 6h 35m 25s   sec/tick 248.08   sec/kimg 15.131  maintenance 0.17    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 1572.9    time 6h 39m 34s   sec/tick 248.65   sec/kimg 15.167  maintenance 0.15    cpumem 3.23   gpumem 7.71   reserved 8.04
# Saving network-snapshot-0001572-0.050.pkl ... done
# Saving network-snapshot-0001572-0.100.pkl ... done
# Status: kimg 1589.2    time 6h 43m 43s   sec/tick 249.29   sec/kimg 15.141  maintenance 1.22    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 1605.6    time 6h 47m 51s   sec/tick 248.38   sec/kimg 15.150  maintenance 0.16    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 1622.0    time 6h 51m 59s   sec/tick 248.08   sec/kimg 15.132  maintenance 0.16    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 1638.4    time 6h 56m 08s   sec/tick 248.62   sec/kimg 15.165  maintenance 0.16    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 1654.8    time 7h 00m 17s   sec/tick 248.60   sec/kimg 15.164  maintenance 0.15    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 1671.2    time 7h 04m 25s   sec/tick 248.69   sec/kimg 15.169  maintenance 0.16    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 1687.6    time 7h 08m 34s   sec/tick 248.69   sec/kimg 15.169  maintenance 0.15    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 1703.9    time 7h 12m 43s   sec/tick 248.53   sec/kimg 15.160  maintenance 0.16    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 1720.3    time 7h 16m 51s   sec/tick 248.67   sec/kimg 15.168  maintenance 0.16    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 1736.7    time 7h 20m 59s   sec/tick 248.25   sec/kimg 15.143  maintenance 0.15    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 1753.1    time 7h 25m 07s   sec/tick 248.05   sec/kimg 15.131  maintenance 0.16    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 1769.5    time 7h 29m 15s   sec/tick 247.81   sec/kimg 15.116  maintenance 0.15    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 1785.9    time 7h 33m 23s   sec/tick 248.12   sec/kimg 15.134  maintenance 0.16    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 1802.2    time 7h 37m 32s   sec/tick 248.79   sec/kimg 15.175  maintenance 0.17    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 1818.6    time 7h 41m 41s   sec/tick 248.60   sec/kimg 15.164  maintenance 0.15    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 1835.0    time 7h 45m 50s   sec/tick 248.96   sec/kimg 15.187  maintenance 0.15    cpumem 3.23   gpumem 7.71   reserved 8.04
# Saving network-snapshot-0001835-0.050.pkl ... done
# Saving network-snapshot-0001835-0.100.pkl ... done
# Status: kimg 1851.4    time 7h 49m 59s   sec/tick 248.98   sec/kimg 15.131  maintenance 1.08    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 1867.8    time 7h 54m 08s   sec/tick 249.20   sec/kimg 15.201  maintenance 0.15    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 1884.2    time 7h 58m 17s   sec/tick 248.69   sec/kimg 15.169  maintenance 0.16    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 1900.5    time 8h 02m 25s   sec/tick 248.39   sec/kimg 15.151  maintenance 0.16    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 1916.9    time 8h 06m 33s   sec/tick 248.12   sec/kimg 15.134  maintenance 0.16    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 1933.3    time 8h 10m 41s   sec/tick 248.06   sec/kimg 15.131  maintenance 0.15    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 1949.7    time 8h 14m 50s   sec/tick 248.69   sec/kimg 15.169  maintenance 0.16    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 1966.1    time 8h 18m 58s   sec/tick 248.24   sec/kimg 15.141  maintenance 0.16    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 1982.5    time 8h 23m 06s   sec/tick 247.62   sec/kimg 15.104  maintenance 0.15    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 1998.8    time 8h 27m 14s   sec/tick 248.51   sec/kimg 15.159  maintenance 0.15    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 2015.2    time 8h 31m 23s   sec/tick 248.42   sec/kimg 15.153  maintenance 0.15    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 2031.6    time 8h 35m 31s   sec/tick 248.58   sec/kimg 15.162  maintenance 0.16    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 2048.0    time 8h 39m 40s   sec/tick 248.34   sec/kimg 15.148  maintenance 0.15    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 2064.4    time 8h 43m 48s   sec/tick 248.42   sec/kimg 15.153  maintenance 0.15    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 2080.8    time 8h 47m 56s   sec/tick 248.17   sec/kimg 15.137  maintenance 0.16    cpumem 3.23   gpumem 7.71   reserved 8.04
# Status: kimg 2097.2    time 8h 52m 04s   sec/tick 247.40   sec/kimg 15.091  maintenance 0.15    cpumem 3.23   gpumem 7.71   reserved 8.04
# Saving network-snapshot-0002097-0.050.pkl ... done
# Saving network-snapshot-0002097-0.100.pkl ... done
# [rank0]:[W1114 11:56:56.415885892 ProcessGroupNCCL.cpp:1496] Warning: WARNING: destroy_process_group() was not called before program exit, which can leak resources. For more info, please see https://pytorch.org/docs/stable/distributed.html#shutdown (function operator())

# %%
# !tail -n 20 /kaggle/working/training-runs/celeba64-edm2-logarithmic/log.txt
# Out:
# tail: cannot open '/kaggle/working/training-runs/celeba64-edm2-logarithmic/log.txt' for reading: No such file or directory
