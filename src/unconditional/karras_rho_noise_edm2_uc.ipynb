# %%
# ============================================================
# ✅ SETUP
# ============================================================

# !git clone https://github.com/NVlabs/edm2.git /kaggle/working/edm2
# %cd /kaggle/working/edm2
# !pip install click tqdm psutil scipy pillow --quiet
# %cd /kaggle/working/edm2
# Out:
# Cloning into '/kaggle/working/edm2'...
# remote: Enumerating objects: 60, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 60 (delta 13), reused 10 (delta 10), pack-reused 33 (from 1)
# Receiving objects: 100% (60/60), 1.27 MiB | 10.26 MiB/s, done.
# Resolving deltas: 100% (24/24), done.
# /kaggle/working/edm2
# /kaggle/working/edm2

# %%
# ============================================================
# ✅ PATCH: KARRAS ρ TRAINING NOISE SCHEDULE (DEFAULT EDM2)
# ============================================================
import torch
import training.training_loop as loop

def karras_sigma(batch_size, device, sigma_min=0.002, sigma_max=80, rho=7.0):
    """
    EDM2 default sampling schedule (Karras et al. 2022):
    
    sigma(t) = (sigma_max^(1/rho) + t * (sigma_min^(1/rho) - sigma_max^(1/rho)))^rho
    where t ~ Uniform[0,1].

    This gives more samples at low noise and fewer at high noise.
    """
    t = torch.rand(batch_size, 1, 1, 1, device=device)

    s0 = sigma_max ** (1 / rho)
    s1 = sigma_min ** (1 / rho)

    sigma = (s0 + t * (s1 - s0)) ** rho
    return sigma


def patched_call(self, net, images, labels=None):
    """
    Override EDM2Loss.__call__ so training uses Karras ρ schedule.
    """
    batch = images.shape[0]

    # === KARRAS POWER-LAW NOISE ===
    sigma = karras_sigma(batch, images.device)

    # === EDM2 weighting ===
    weight = (sigma**2 + self.sigma_data**2) / (sigma * self.sigma_data)**2

    # Add noise
    noise = torch.randn_like(images) * sigma

    # Forward pass
    denoised, logvar = net(images + noise, sigma, labels, return_logvar=True)

    # Loss formula
    loss = (weight / logvar.exp()) * ((denoised - images)**2) + logvar
    return loss


# Inject patch into EDM2
loop.EDM2Loss.__call__ = patched_call

print("✅ Karras ρ schedule injected successfully!")
# Out:
# ✅ Karras ρ schedule injected successfully!

# %%
# !torchrun --standalone --nproc_per_node=2 train_edm2.py \
    --outdir=/kaggle/working/training-runs/celeba64-karras-rho \
    --data=/kaggle/input/celeva-64x64-dataset/celeba64/train \
    --cond=False \
    --preset=edm2-img64-xs \
    --batch=64 \
    --batch-gpu=32 \
    --duration=2Mi \
    --status=16Ki \
    --snapshot=512Ki \
    --checkpoint=0 \
    --seed=0
# Out:
# W1114 03:04:57.175000 54 torch/distributed/run.py:792]
# W1114 03:04:57.175000 54 torch/distributed/run.py:792] *****************************************
# W1114 03:04:57.175000 54 torch/distributed/run.py:792] Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# W1114 03:04:57.175000 54 torch/distributed/run.py:792] *****************************************
# [W1114 03:05:07.025224929 socket.cpp:204] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# [W1114 03:05:17.031068196 socket.cpp:204] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# [W1114 03:05:29.815892787 socket.cpp:204] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# [W1114 03:05:29.830519255 socket.cpp:204] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# [W1114 03:05:39.826525176 socket.cpp:204] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# [W1114 03:05:49.837041045 socket.cpp:204] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# Setting up training config...
#
# Training config:
# {
#   "dataset_kwargs": {
#     "class_name": "training.dataset.ImageFolderDataset",
#     "path": "/kaggle/input/celeva-64x64-dataset/celeba64/train",
#     "use_labels": false
#   },
#   "encoder_kwargs": {
#     "class_name": "training.encoders.StandardRGBEncoder"
#   },
#   "total_nimg": 2097152,
#   "batch_size": 64,
#   "network_kwargs": {
#     "class_name": "training.networks_edm2.Precond",
#     "model_channels": 128,
#     "dropout": 0.0,
#     "use_fp16": true
#   },
#   "loss_kwargs": {
#     "class_name": "training.training_loop.EDM2Loss",
#     "P_mean": -0.8,
#     "P_std": 1.6
#   },
#   "lr_kwargs": {
#     "func_name": "training.training_loop.learning_rate_schedule",
#     "ref_lr": 0.012,
#     "ref_batches": 35000
#   },
#   "batch_gpu": 32,
#   "loss_scaling": 1.0,
#   "cudnn_benchmark": true,
#   "status_nimg": 16384,
#   "snapshot_nimg": 524288,
#   "checkpoint_nimg": null,
#   "seed": 0
# }
#
# Output directory:        /kaggle/working/training-runs/celeba64-karras-rho
# Dataset path:            /kaggle/input/celeva-64x64-dataset/celeba64/train
# Class-conditional:       False
# Number of GPUs:          2
# Batch size:              64
# Mixed-precision:         True
#
# Creating output directory...
# [rank1]:[W1114 03:11:47.803541533 ProcessGroupNCCL.cpp:4561] [PG ID 0 PG GUID 0 Rank 1]  using GPU 1 to perform barrier as devices used by this process are currently unknown. This can potentially cause a hang if this rank to GPU mapping is incorrect. Specify device_ids in barrier() to force use of a particular device, or call init_process_group() with a device_id.
# [rank0]:[W1114 03:11:47.911302147 ProcessGroupNCCL.cpp:4561] [PG ID 0 PG GUID 0 Rank 0]  using GPU 0 to perform barrier as devices used by this process are currently unknown. This can potentially cause a hang if this rank to GPU mapping is incorrect. Specify device_ids in barrier() to force use of a particular device, or call init_process_group() with a device_id.
# Loading dataset...
# Setting up encoder...
# Constructing network...
#
# Precond                Parameters  Buffers  Output shape       Datatype
# ---                    ---         ---      ---                ---
# unet.emb_fourier       -           256      [32, 128]          float32
# unet.emb_noise         65536       -        [32, 512]          float32
# unet.enc.64x64_conv    4608        -        [32, 128, 64, 64]  float16
# unet.enc.64x64_block0  360449      -        [32, 128, 64, 64]  float16
# unet.enc.64x64_block1  360449      -        [32, 128, 64, 64]  float16
# unet.enc.64x64_block2  360449      -        [32, 128, 64, 64]  float16
# unet.enc.32x32_down    360449      -        [32, 128, 32, 32]  float16
# unet.enc.32x32_block0  1343489     -        [32, 256, 32, 32]  float16
# unet.enc.32x32_block1  1310721     -        [32, 256, 32, 32]  float16
# unet.enc.32x32_block2  1310721     -        [32, 256, 32, 32]  float16
# unet.enc.16x16_down    1310721     -        [32, 256, 16, 16]  float16
# unet.enc.16x16_block0  3538945     -        [32, 384, 16, 16]  float16
# unet.enc.16x16_block1  3440641     -        [32, 384, 16, 16]  float16
# unet.enc.16x16_block2  3440641     -        [32, 384, 16, 16]  float16
# unet.enc.8x8_down      2850817     -        [32, 384, 8, 8]    float16
# unet.enc.8x8_block0    6225921     -        [32, 512, 8, 8]    float16
# unet.enc.8x8_block1    6029313     -        [32, 512, 8, 8]    float16
# unet.enc.8x8_block2    6029313     -        [32, 512, 8, 8]    float16
# unet.dec.8x8_in0       6029313     -        [32, 512, 8, 8]    float16
# unet.dec.8x8_in1       4980737     -        [32, 512, 8, 8]    float16
# unet.dec.8x8_block0    8912897     -        [32, 512, 8, 8]    float16
# unet.dec.8x8_block1    8912897     -        [32, 512, 8, 8]    float16
# unet.dec.8x8_block2    8912897     -        [32, 512, 8, 8]    float16
# unet.dec.8x8_block3    8257537     -        [32, 512, 8, 8]    float16
# unet.dec.16x16_up      4980737     -        [32, 512, 16, 16]  float16
# unet.dec.16x16_block0  5554177     -        [32, 384, 16, 16]  float16
# unet.dec.16x16_block1  5062657     -        [32, 384, 16, 16]  float16
# unet.dec.16x16_block2  5062657     -        [32, 384, 16, 16]  float16
# unet.dec.16x16_block3  4571137     -        [32, 384, 16, 16]  float16
# unet.dec.32x32_up      2850817     -        [32, 384, 32, 32]  float16
# unet.dec.32x32_block0  2359297     -        [32, 256, 32, 32]  float16
# unet.dec.32x32_block1  2031617     -        [32, 256, 32, 32]  float16
# unet.dec.32x32_block2  2031617     -        [32, 256, 32, 32]  float16
# unet.dec.32x32_block3  1703937     -        [32, 256, 32, 32]  float16
# unet.dec.64x64_up      1310721     -        [32, 256, 64, 64]  float16
# unet.dec.64x64_block0  704513      -        [32, 128, 64, 64]  float16
# unet.dec.64x64_block1  540673      -        [32, 128, 64, 64]  float16
# unet.dec.64x64_block2  540673      -        [32, 128, 64, 64]  float16
# unet.dec.64x64_block3  540673      -        [32, 128, 64, 64]  float16
# unet.out_conv          3456        -        [32, 3, 64, 64]    float16
# unet                   1           -        [32, 3, 64, 64]    float16
# <top-level>            128         256      [32, 3, 64, 64]    float32
# ---                    ---         ---      ---                ---
# Total                  124198949   512      -                  -
#
# Setting up training state...
# Training from 0 kimg to 2097 kimg:
#
# Status: kimg 0.0       time 1m 01s       sec/tick 61.11    sec/kimg 0.000   maintenance 61.11   cpumem 2.44   gpumem 1.87   reserved 2.28
# Saving network-snapshot-0000000-0.050.pkl ... done
# Saving network-snapshot-0000000-0.100.pkl ... done
# Status: kimg 16.4      time 4m 45s       sec/tick 224.25   sec/kimg 13.602  maintenance 1.39    cpumem 3.11   gpumem 7.70   reserved 8.04
# Status: kimg 32.8      time 8m 30s       sec/tick 224.93   sec/kimg 13.723  maintenance 0.09    cpumem 3.11   gpumem 7.70   reserved 8.04
# Status: kimg 49.2      time 12m 16s      sec/tick 225.44   sec/kimg 13.754  maintenance 0.09    cpumem 3.11   gpumem 7.70   reserved 8.04
# Status: kimg 65.5      time 16m 02s      sec/tick 226.57   sec/kimg 13.823  maintenance 0.09    cpumem 3.11   gpumem 7.70   reserved 8.04
# Status: kimg 81.9      time 19m 50s      sec/tick 227.40   sec/kimg 13.874  maintenance 0.09    cpumem 3.11   gpumem 7.70   reserved 8.04
# Status: kimg 98.3      time 23m 37s      sec/tick 227.69   sec/kimg 13.892  maintenance 0.09    cpumem 3.11   gpumem 7.70   reserved 8.04
# Status: kimg 114.7     time 27m 25s      sec/tick 227.78   sec/kimg 13.897  maintenance 0.09    cpumem 3.11   gpumem 7.70   reserved 8.04
# Status: kimg 131.1     time 31m 13s      sec/tick 228.25   sec/kimg 13.926  maintenance 0.09    cpumem 3.11   gpumem 7.70   reserved 8.04
# Status: kimg 147.5     time 35m 02s      sec/tick 228.60   sec/kimg 13.947  maintenance 0.09    cpumem 3.11   gpumem 7.70   reserved 8.04
# Status: kimg 163.8     time 38m 50s      sec/tick 228.02   sec/kimg 13.911  maintenance 0.09    cpumem 3.11   gpumem 7.70   reserved 8.04
# Status: kimg 180.2     time 42m 38s      sec/tick 228.35   sec/kimg 13.932  maintenance 0.09    cpumem 3.11   gpumem 7.70   reserved 8.04
# Status: kimg 196.6     time 46m 27s      sec/tick 228.21   sec/kimg 13.923  maintenance 0.09    cpumem 3.11   gpumem 7.70   reserved 8.04
# Status: kimg 213.0     time 50m 16s      sec/tick 228.99   sec/kimg 13.971  maintenance 0.09    cpumem 3.11   gpumem 7.70   reserved 8.04
# Status: kimg 229.4     time 54m 04s      sec/tick 228.31   sec/kimg 13.930  maintenance 0.09    cpumem 3.11   gpumem 7.70   reserved 8.04
# Status: kimg 245.8     time 57m 53s      sec/tick 228.97   sec/kimg 13.970  maintenance 0.09    cpumem 3.11   gpumem 7.70   reserved 8.04
# Status: kimg 262.1     time 1h 01m 42s   sec/tick 229.53   sec/kimg 14.004  maintenance 0.09    cpumem 3.11   gpumem 7.70   reserved 8.04
# Status: kimg 278.5     time 1h 05m 32s   sec/tick 229.54   sec/kimg 14.005  maintenance 0.09    cpumem 3.11   gpumem 7.70   reserved 8.04
# Status: kimg 294.9     time 1h 09m 21s   sec/tick 229.02   sec/kimg 13.973  maintenance 0.09    cpumem 3.11   gpumem 7.70   reserved 8.04
# Status: kimg 311.3     time 1h 13m 10s   sec/tick 228.57   sec/kimg 13.945  maintenance 0.09    cpumem 3.11   gpumem 7.70   reserved 8.04
# Status: kimg